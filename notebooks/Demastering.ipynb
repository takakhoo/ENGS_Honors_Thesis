# %%
# Check that the dependencies in your conda environment are available.
import torch
print("PyTorch version:", torch.__version__)

import torchaudio
print("torchaudio version:", torchaudio.__version__)

import librosa
print("Librosa version:", librosa.__version__)

import numpy as np
print("NumPy version:", np.__version__)

import pandas as pd
print("Pandas version:", pd.__version__)

import matplotlib
print("Matplotlib version:", matplotlib.__version__)

import scipy
print("SciPy version:", scipy.__version__)
# Out:
# PyTorch version: 2.6.0+cu126
# torchaudio version: 2.6.0+cu126
# Librosa version: 0.10.2.post1
# NumPy version: 1.22.4
# Pandas version: 1.5.3
# Matplotlib version: 3.8.4
# SciPy version: 1.8.1

# %% [markdown]
# # Demastering a Song from the FMA Dataset
#
# This notebook demonstrates a simple "demastering" process. We will:
# 1. Load full tracks from the FMA dataset.
# 2. Apply several degradation functions to the entire track using random parameters—this includes EQ, gain adjustment, echo, reverb, and compression.
# 3. Display the STFT (spectrogram) of the original and degraded tracks.
# 4. Save the processed audio along with the original for future dataset creation.
#
# > **Note:**
# > - Ensure you update the `song_path` variable below to point to a valid audio file from your FMA data (e.g., from the `data/fma_small/` folder).
# > - This notebook is saved in the "ENGS Honors Thesis" folder.

# %%
import os
import glob
import random
import librosa.display
import matplotlib.pyplot as plt
import soundfile as sf
from scipy.signal import iirpeak, lfilter, fftconvolve
import shutil
import numpy as np

print("Current working directory:", os.getcwd())

def plot_stft(audio, sr, title, extra_info = None):
    D = librosa.stft(audio)  # Compute STFT
    DB = librosa.amplitude_to_db(np.abs(D), ref=np.max)  # Convert amplitude to dB
    
    fig, ax = plt.subplots(figsize=(12, 6))
    
    img = librosa.display.specshow(DB, sr=sr, x_axis='time', y_axis='hz', ax=ax)
    cbar = fig.colorbar(img, ax=ax, format='%+2.0f dB')
    cbar.set_label("Amplitude (dB)", fontsize=12)
    
    ax.set_title(title, fontsize = 16)
    ax.set_xlabel("Time (s)", fontsize = 14)
    ax.set_ylabel("Frequency (Hz)", fontsize = 14)
    
    if extra_info:
            ax.text(0.01, 0.01, extra_info, transform=ax.transAxes,
                fontsize=12, verticalalignment='bottom',
                bbox=dict(boxstyle="round,pad=0.5", fc="yellow", alpha=0.5))
    plt.tight_layout()
    return fig
    
def apply_eq(audio, sr, fc, Q, gain_db):
    """
    Applying a random EQ (peaking filter) to the audio signal 
    to simulate an unmastered version
    
    Parameters audio (np.array): Input Audio Waveform, sr (int): Sample Rate
    
    Returns filtered_audio (np.array): EQ Processed audio
    """
    
    #Normalizing center frequency for iirpear (w0 in [0,1], where 1 = Nyquist Frequency)
    w0 = fc / (sr/2)
    b,a = iirpeak(w0,Q) #Design peak filter: iirpeak returns filter coefficients
    gain_linear = 10 ** (gain_db / 20.0)
    b=b*gain_linear #Scale filter numerator to apply gain
    return lfilter(b, a, audio)

def apply_gain(audio, gain_db):
    """Apply a gain adjustment in dB to the audio"""
    gain_linear = 10**(gain_db/20.0)
    return audio * gain_linear

def apply_echo(audio, sr, delay_seconds, attenuation):
    """Apply echo effect by adding delayed, attenuated copy of the audio"""
    
    delay_samples = int(sr * delay_seconds)
    echo = np.zeros_like(audio)
    if len(audio) > delay_samples:
        echo[delay_samples:] = audio[:-delay_samples] * attenuation
    return audio + echo

def apply_reverb(audio, sr, decay, ir_length):
    """
    Apply a simple reverb effect by convolving the audio with a synthetic impulse response.
    
    Parameters:
    audio: input audio (numpy array)
    decay: decay rate for the exponential impulse response
    ir_length: length of the impulse response in samples
    sr: sampling rate
    """
    # Ensure ir_length is an integer and positive
    ir_length = int(ir_length)
    print("Inside apply_reverb: received ir_length =", ir_length)
    if ir_length <= 0:
        raise ValueError("ir_length must be positive, but got {}".format(ir_length))
    t = np.linspace(0, ir_length / sr, ir_length)
    ir = np.exp(-decay * t)
    try:
        result = fftconvolve(audio, ir, mode='same')
        if result.size == 0:
            raise ValueError("fftconvolve returned an empty array")
    except Exception as e:
        print(f"fftconvolve failed ({e}); using np.convolve instead.")
        result = np.convolve(audio, ir, mode='same')
    if result.size == 0:
        print("Warning: apply_reverb resulted in an empty array; returning original audio.")
        return audio
    return result

def apply_compression(audio, threshold_db, ratio, makeup_gain_db):
    """
    Apply a basic dynamic range compression to the audio.
    
    Parameters:
    audio: input audio (numpy array)
    threshold_db: threshold (in dB) above which compression occurs
    ratio: compression ratio
    makeup_gain_db: makeup gain in dB applied after compression
    """
    threshold_linear = 10**(threshold_db / 20.0)
    
    abs_audio = np.abs(audio)
    compressed = np.where(abs_audio > threshold_linear,
                        threshold_linear + (abs_audio - threshold_linear) / ratio,
                        abs_audio)
    compressed = np.sign(audio) * compressed
    makeup_gain = 10 ** (makeup_gain_db / 20.0)
    return compressed * makeup_gain
# Out:
# Current working directory: c:\Users\takak\OneDrive\Desktop\ENGS Honors Thesis\notebooks

# %%
base_output_dir = os.path.join("..","experiments","output_full")
output_audio_dir = os.path.join(base_output_dir, "output_audio")
output_spectrogram_dir = os.path.join(base_output_dir, "output_spectrograms")
output_txt_dir = os.path.join(base_output_dir, "output_txt")

for folder in [output_audio_dir, output_spectrogram_dir, output_txt_dir]:
    if os.path.exists(folder):
        shutil.rmtree(folder)
    os.makedirs(folder, exist_ok = True)

base_input_folder = os.path.join("..", "data", "raw", "fma_small")
subfolders = [name for name in os.listdir(base_input_folder)
            if os.path.isdir(os.path.join(base_input_folder, name))]

# Loop over subfolders and process each MP3 file found
for sub in subfolders:
    folder_path = os.path.join(base_input_folder, sub)
    mp3_files = glob.glob(os.path.join(folder_path, "*.mp3"))
    for song_path in mp3_files:
        print(f"Processing song: {song_path}")
        
        # Load audio
        audio, sr = librosa.load(song_path, sr=None)
        if len(audio) == 0:
            print(f"Warning: Audio from {song_path} is empty. Skipping.")
            continue
        
        # Generate a unique identifier based on file name
        song_id = os.path.splitext(os.path.basename(song_path))[0]
        
        # Save original spectrogram
        fig_orig = plot_stft(audio, sr, f"Original Audio STFT - {song_id}")
        orig_spec_path = os.path.join(output_spectrogram_dir, f"{song_id}_input.png")
        fig_orig.savefig(orig_spec_path)
        plt.close(fig_orig)
        
        # Randomly generate parameters (adjust these ranges as desired for realistic effects)
        # EQ parameters:
        fc = random.uniform(200, 8000)         # Center frequency in Hz
        Q = random.uniform(0.7, 2.5)             # Q-factor
        eq_gain_db = random.uniform(-2, 2)       # EQ gain adjustment in dB
        
        # Gain adjustment:
        gain_db = random.uniform(-1, 1)
        
        # Echo:
        delay_seconds = random.uniform(0.3, 1.0)  # Allow bigger echoes
        attenuation = random.uniform(0.3, 0.5)
        
        # Reverb:
        decay = random.uniform(0.2, 1.0)
        lower_ir = max(int(0.1 * sr), 1)
        upper_ir = max(int(0.3 * sr), lower_ir + 1)
        ir_length = random.randint(lower_ir, upper_ir)
        
        # Compression:
        threshold_db = random.uniform(-20, -12)
        ratio = random.uniform(2, 3)
        makeup_gain_db = random.uniform(0, 0.5)
        
        # Save the parameters to a text file
        txt_path = os.path.join(output_txt_dir, f"{song_id}_params.txt")
        with open(txt_path, "w") as f:
            f.write(f"EQ: fc={fc:.2f} Hz, Q={Q:.2f}, eq_gain_db={eq_gain_db:.2f}\n")
            f.write(f"Gain: gain_db={gain_db:.2f}\n")
            f.write(f"Echo: delay_seconds={delay_seconds:.2f}, attenuation={attenuation:.2f}\n")
            f.write(f"Reverb: decay={decay:.2f}, ir_length={ir_length}\n")
            f.write(f"Compression: threshold_db={threshold_db:.2f}, ratio={ratio:.2f}, makeup_gain_db={makeup_gain_db:.2f}\n")
        
        print(f"Parameters for {song_id} saved to {txt_path}")
        
        # Apply degradation effects sequentially
        modified_audio = apply_eq(audio, sr, fc, Q, eq_gain_db)
        modified_audio = apply_gain(modified_audio, gain_db)
        modified_audio = apply_echo(modified_audio, sr, delay_seconds, attenuation)
        modified_audio = apply_reverb(modified_audio, sr, decay, ir_length)
        modified_audio = apply_compression(modified_audio, threshold_db, ratio, makeup_gain_db)
        
        #Saving modified spectrogram image with extra info annotation
        extra = (f"EQ: fc={fc:.2f} Hz, Q={Q:.2f}, gain_db={eq_gain_db:.2f}\n"
                f"Gain: {gain_db:.2f} dB\n"
                f"Echo: delay={delay_seconds:.2f}s, att={attenuation:.2f}\n"
                f"Reverb: decay={decay:.2f}, IR_len={ir_length}\n"
                f"Comp: thr={threshold_db:.2f} dB, ratio={ratio:.2f}, makeup={makeup_gain_db:.2f} dB")
        fig_mod = plot_stft(modified_audio, sr, f"Modified Audio STFT - {song_id}", extra_info=extra)
        mod_spec_path = os.path.join(output_spectrogram_dir, f"{song_id}_output.png")
        fig_mod.savefig(mod_spec_path)
        plt.close(fig_mod)
        
        # Save original and modified audio files
        orig_audio_path = os.path.join(output_audio_dir, f"{song_id}_original.wav")
        mod_audio_path = os.path.join(output_audio_dir, f"{song_id}_modified.wav")
        sf.write(orig_audio_path, audio, sr)
        sf.write(mod_audio_path, modified_audio, sr)
        
        print(f"Saved audio for {song_id} to {output_audio_dir}\n")
# Out:
# Processing song: ..\data\raw\fma_small\000\000002.mp3
# Parameters for 000002 saved to ..\experiments\output_full\output_txt\000002_params.txt
# Inside apply_reverb: received ir_length = 11474
# Saved audio for 000002 to ..\experiments\output_full\output_audio
#
# Processing song: ..\data\raw\fma_small\000\000005.mp3
# Parameters for 000005 saved to ..\experiments\output_full\output_txt\000005_params.txt
# Inside apply_reverb: received ir_length = 9079
# Saved audio for 000005 to ..\experiments\output_full\output_audio
#
# Processing song: ..\data\raw\fma_small\000\000010.mp3
# Parameters for 000010 saved to ..\experiments\output_full\output_txt\000010_params.txt
# Inside apply_reverb: received ir_length = 7431
# Saved audio for 000010 to ..\experiments\output_full\output_audio
#
# Processing song: ..\data\raw\fma_small\000\000140.mp3
# Parameters for 000140 saved to ..\experiments\output_full\output_txt\000140_params.txt
# Inside apply_reverb: received ir_length = 13028
# Saved audio for 000140 to ..\experiments\output_full\output_audio
#
# Processing song: ..\data\raw\fma_small\000\000141.mp3
# Parameters for 000141 saved to ..\experiments\output_full\output_txt\000141_params.txt
# Inside apply_reverb: received ir_length = 8567
# Saved audio for 000141 to ..\experiments\output_full\output_audio
#
# Processing song: ..\data\raw\fma_small\000\000148.mp3
# Parameters for 000148 saved to ..\experiments\output_full\output_txt\000148_params.txt
# Inside apply_reverb: received ir_length = 5444
# Saved audio for 000148 to ..\experiments\output_full\output_audio
#
# Processing song: ..\data\raw\fma_small\000\000182.mp3
# Parameters for 000182 saved to ..\experiments\output_full\output_txt\000182_params.txt
# Inside apply_reverb: received ir_length = 12087
# Saved audio for 000182 to ..\experiments\output_full\output_audio
#
# Processing song: ..\data\raw\fma_small\000\000190.mp3
# Parameters for 000190 saved to ..\experiments\output_full\output_txt\000190_params.txt
# Inside apply_reverb: received ir_length = 11666
# Saved audio for 000190 to ..\experiments\output_full\output_audio
#
# Processing song: ..\data\raw\fma_small\000\000193.mp3
# Parameters for 000193 saved to ..\experiments\output_full\output_txt\000193_params.txt
# Inside apply_reverb: received ir_length = 11086
# Saved audio for 000193 to ..\experiments\output_full\output_audio
#
# Processing song: ..\data\raw\fma_small\000\000194.mp3
# Parameters for 000194 saved to ..\experiments\output_full\output_txt\000194_params.txt
# Inside apply_reverb: received ir_length = 6564
# Saved audio for 000194 to ..\experiments\output_full\output_audio
#
# Processing song: ..\data\raw\fma_small\000\000197.mp3
# Parameters for 000197 saved to ..\experiments\output_full\output_txt\000197_params.txt
# Inside apply_reverb: received ir_length = 5125
# Saved audio for 000197 to ..\experiments\output_full\output_audio
#
# Processing song: ..\data\raw\fma_small\000\000200.mp3
# Parameters for 000200 saved to ..\experiments\output_full\output_txt\000200_params.txt
# Inside apply_reverb: received ir_length = 6711
# Saved audio for 000200 to ..\experiments\output_full\output_audio
#
# Processing song: ..\data\raw\fma_small\000\000203.mp3
# Parameters for 000203 saved to ..\experiments\output_full\output_txt\000203_params.txt
# Inside apply_reverb: received ir_length = 11520
# Saved audio for 000203 to ..\experiments\output_full\output_audio
#
# Processing song: ..\data\raw\fma_small\000\000204.mp3
# Parameters for 000204 saved to ..\experiments\output_full\output_txt\000204_params.txt
# Inside apply_reverb: received ir_length = 12456
# Saved audio for 000204 to ..\experiments\output_full\output_audio
#
# Processing song: ..\data\raw\fma_small\000\000207.mp3
# Parameters for 000207 saved to ..\experiments\output_full\output_txt\000207_params.txt
# Inside apply_reverb: received ir_length = 4443
# Saved audio for 000207 to ..\experiments\output_full\output_audio
#
# Processing song: ..\data\raw\fma_small\000\000210.mp3
# Parameters for 000210 saved to ..\experiments\output_full\output_txt\000210_params.txt
# Inside apply_reverb: received ir_length = 6910
# Saved audio for 000210 to ..\experiments\output_full\output_audio
#
# Processing song: ..\data\raw\fma_small\000\000211.mp3
# Parameters for 000211 saved to ..\experiments\output_full\output_txt\000211_params.txt
# Inside apply_reverb: received ir_length = 6082
# Saved audio for 000211 to ..\experiments\output_full\output_audio
#
# Processing song: ..\data\raw\fma_small\000\000212.mp3
# Parameters for 000212 saved to ..\experiments\output_full\output_txt\000212_params.txt
# Inside apply_reverb: received ir_length = 12291
# Saved audio for 000212 to ..\experiments\output_full\output_audio
#
# Processing song: ..\data\raw\fma_small\000\000213.mp3
# Parameters for 000213 saved to ..\experiments\output_full\output_txt\000213_params.txt
# Inside apply_reverb: received ir_length = 8148
# Saved audio for 000213 to ..\experiments\output_full\output_audio
#
# Processing song: ..\data\raw\fma_small\000\000255.mp3
# Parameters for 000255 saved to ..\experiments\output_full\output_txt\000255_params.txt
# Inside apply_reverb: received ir_length = 13161
# Saved audio for 000255 to ..\experiments\output_full\output_audio
#
# Processing song: ..\data\raw\fma_small\000\000256.mp3
# Parameters for 000256 saved to ..\experiments\output_full\output_txt\000256_params.txt
# Inside apply_reverb: received ir_length = 7270
# Saved audio for 000256 to ..\experiments\output_full\output_audio
#
# Processing song: ..\data\raw\fma_small\000\000368.mp3
# Parameters for 000368 saved to ..\experiments\output_full\output_txt\000368_params.txt
# Inside apply_reverb: received ir_length = 13223
# Saved audio for 000368 to ..\experiments\output_full\output_audio
#
# Processing song: ..\data\raw\fma_small\000\000424.mp3
# Parameters for 000424 saved to ..\experiments\output_full\output_txt\000424_params.txt
# Inside apply_reverb: received ir_length = 12910
# Saved audio for 000424 to ..\experiments\output_full\output_audio
#
# Processing song: ..\data\raw\fma_small\000\000459.mp3
# Parameters for 000459 saved to ..\experiments\output_full\output_txt\000459_params.txt
# Inside apply_reverb: received ir_length = 9181
# Saved audio for 000459 to ..\experiments\output_full\output_audio
#
# Processing song: ..\data\raw\fma_small\000\000534.mp3
# Parameters for 000534 saved to ..\experiments\output_full\output_txt\000534_params.txt
# Inside apply_reverb: received ir_length = 9419
# Saved audio for 000534 to ..\experiments\output_full\output_audio
#
# Processing song: ..\data\raw\fma_small\000\000540.mp3
# Parameters for 000540 saved to ..\experiments\output_full\output_txt\000540_params.txt
# Inside apply_reverb: received ir_length = 8772
# Saved audio for 000540 to ..\experiments\output_full\output_audio
#
# Processing song: ..\data\raw\fma_small\000\000546.mp3
# Parameters for 000546 saved to ..\experiments\output_full\output_txt\000546_params.txt
# Inside apply_reverb: received ir_length = 12402
# Saved audio for 000546 to ..\experiments\output_full\output_audio
#
# Processing song: ..\data\raw\fma_small\000\000574.mp3
# Parameters for 000574 saved to ..\experiments\output_full\output_txt\000574_params.txt
# Inside apply_reverb: received ir_length = 12829
# Saved audio for 000574 to ..\experiments\output_full\output_audio
#
# Processing song: ..\data\raw\fma_small\000\000602.mp3
# Parameters for 000602 saved to ..\experiments\output_full\output_txt\000602_params.txt
# Inside apply_reverb: received ir_length = 9788
# Saved audio for 000602 to ..\experiments\output_full\output_audio
#
# Processing song: ..\data\raw\fma_small\000\000615.mp3
# Parameters for 000615 saved to ..\experiments\output_full\output_txt\000615_params.txt
# Inside apply_reverb: received ir_length = 7765
# Saved audio for 000615 to ..\experiments\output_full\output_audio
#
# Processing song: ..\data\raw\fma_small\000\000620.mp3
# Parameters for 000620 saved to ..\experiments\output_full\output_txt\000620_params.txt
# Inside apply_reverb: received ir_length = 12639
# Saved audio for 000620 to ..\experiments\output_full\output_audio
#
# Processing song: ..\data\raw\fma_small\000\000621.mp3
# Parameters for 000621 saved to ..\experiments\output_full\output_txt\000621_params.txt
# Inside apply_reverb: received ir_length = 5902
# Saved audio for 000621 to ..\experiments\output_full\output_audio
#
# Processing song: ..\data\raw\fma_small\000\000625.mp3
# Parameters for 000625 saved to ..\experiments\output_full\output_txt\000625_params.txt
# Inside apply_reverb: received ir_length = 9528
# Saved audio for 000625 to ..\experiments\output_full\output_audio
#
# Processing song: ..\data\raw\fma_small\000\000666.mp3
# Parameters for 000666 saved to ..\experiments\output_full\output_txt\000666_params.txt
# Inside apply_reverb: received ir_length = 6881
# Saved audio for 000666 to ..\experiments\output_full\output_audio
#
# Processing song: ..\data\raw\fma_small\000\000667.mp3
# Parameters for 000667 saved to ..\experiments\output_full\output_txt\000667_params.txt
# Inside apply_reverb: received ir_length = 10209
# Saved audio for 000667 to ..\experiments\output_full\output_audio
#
# Processing song: ..\data\raw\fma_small\000\000676.mp3
# Parameters for 000676 saved to ..\experiments\output_full\output_txt\000676_params.txt
# Inside apply_reverb: received ir_length = 9475
# Saved audio for 000676 to ..\experiments\output_full\output_audio
#
# Processing song: ..\data\raw\fma_small\000\000690.mp3
# Parameters for 000690 saved to ..\experiments\output_full\output_txt\000690_params.txt
# Inside apply_reverb: received ir_length = 10451
# Saved audio for 000690 to ..\experiments\output_full\output_audio
#
# Processing song: ..\data\raw\fma_small\000\000694.mp3
# Parameters for 000694 saved to ..\experiments\output_full\output_txt\000694_params.txt
# Inside apply_reverb: received ir_length = 4864
# Saved audio for 000694 to ..\experiments\output_full\output_audio
#
# Processing song: ..\data\raw\fma_small\000\000695.mp3
# Parameters for 000695 saved to ..\experiments\output_full\output_txt\000695_params.txt
# Inside apply_reverb: received ir_length = 11284
# Saved audio for 000695 to ..\experiments\output_full\output_audio
#
# Processing song: ..\data\raw\fma_small\000\000704.mp3
# Parameters for 000704 saved to ..\experiments\output_full\output_txt\000704_params.txt
# Inside apply_reverb: received ir_length = 8443
# Saved audio for 000704 to ..\experiments\output_full\output_audio
#
# Processing song: ..\data\raw\fma_small\000\000705.mp3
# Parameters for 000705 saved to ..\experiments\output_full\output_txt\000705_params.txt
# Inside apply_reverb: received ir_length = 9050
# Saved audio for 000705 to ..\experiments\output_full\output_audio
#
# Processing song: ..\data\raw\fma_small\000\000706.mp3
# Parameters for 000706 saved to ..\experiments\output_full\output_txt\000706_params.txt
# Inside apply_reverb: received ir_length = 13184
# Saved audio for 000706 to ..\experiments\output_full\output_audio
#
# Processing song: ..\data\raw\fma_small\000\000707.mp3
# Parameters for 000707 saved to ..\experiments\output_full\output_txt\000707_params.txt
# Inside apply_reverb: received ir_length = 12070
# Saved audio for 000707 to ..\experiments\output_full\output_audio
#
# Processing song: ..\data\raw\fma_small\000\000708.mp3
# Parameters for 000708 saved to ..\experiments\output_full\output_txt\000708_params.txt
# Inside apply_reverb: received ir_length = 9621
# Saved audio for 000708 to ..\experiments\output_full\output_audio
#
# Processing song: ..\data\raw\fma_small\000\000709.mp3
# Parameters for 000709 saved to ..\experiments\output_full\output_txt\000709_params.txt
# Inside apply_reverb: received ir_length = 11054
# Saved audio for 000709 to ..\experiments\output_full\output_audio
#
# Processing song: ..\data\raw\fma_small\000\000714.mp3
# Parameters for 000714 saved to ..\experiments\output_full\output_txt\000714_params.txt
# Inside apply_reverb: received ir_length = 9628
# Saved audio for 000714 to ..\experiments\output_full\output_audio
#
# Processing song: ..\data\raw\fma_small\000\000715.mp3
# Parameters for 000715 saved to ..\experiments\output_full\output_txt\000715_params.txt
# Inside apply_reverb: received ir_length = 6960
# Saved audio for 000715 to ..\experiments\output_full\output_audio
#
# Processing song: ..\data\raw\fma_small\000\000716.mp3
# Parameters for 000716 saved to ..\experiments\output_full\output_txt\000716_params.txt
# Inside apply_reverb: received ir_length = 12830
# Saved audio for 000716 to ..\experiments\output_full\output_audio
#
# Processing song: ..\data\raw\fma_small\000\000718.mp3
# Parameters for 000718 saved to ..\experiments\output_full\output_txt\000718_params.txt
# Inside apply_reverb: received ir_length = 5919
# Saved audio for 000718 to ..\experiments\output_full\output_audio
#
# Processing song: ..\data\raw\fma_small\000\000777.mp3
# Parameters for 000777 saved to ..\experiments\output_full\output_txt\000777_params.txt
# Inside apply_reverb: received ir_length = 7082
# Saved audio for 000777 to ..\experiments\output_full\output_audio
#
# Processing song: ..\data\raw\fma_small\000\000814.mp3
# Parameters for 000814 saved to ..\experiments\output_full\output_txt\000814_params.txt
# Inside apply_reverb: received ir_length = 10001
# Saved audio for 000814 to ..\experiments\output_full\output_audio
#
# Processing song: ..\data\raw\fma_small\000\000821.mp3
# Parameters for 000821 saved to ..\experiments\output_full\output_txt\000821_params.txt
# Inside apply_reverb: received ir_length = 7823
# Saved audio for 000821 to ..\experiments\output_full\output_audio
#
# Processing song: ..\data\raw\fma_small\000\000822.mp3
# Parameters for 000822 saved to ..\experiments\output_full\output_txt\000822_params.txt
# Inside apply_reverb: received ir_length = 10520
# Saved audio for 000822 to ..\experiments\output_full\output_audio
#
# Processing song: ..\data\raw\fma_small\000\000825.mp3
# Parameters for 000825 saved to ..\experiments\output_full\output_txt\000825_params.txt
# Inside apply_reverb: received ir_length = 8457
# Saved audio for 000825 to ..\experiments\output_full\output_audio
#
# Processing song: ..\data\raw\fma_small\000\000853.mp3
# Parameters for 000853 saved to ..\experiments\output_full\output_txt\000853_params.txt
# Inside apply_reverb: received ir_length = 8397
# Saved audio for 000853 to ..\experiments\output_full\output_audio
#
# Processing song: ..\data\raw\fma_small\000\000890.mp3
# Parameters for 000890 saved to ..\experiments\output_full\output_txt\000890_params.txt
# Inside apply_reverb: received ir_length = 10896
# Saved audio for 000890 to ..\experiments\output_full\output_audio
#
# Processing song: ..\data\raw\fma_small\000\000892.mp3
# Parameters for 000892 saved to ..\experiments\output_full\output_txt\000892_params.txt
# Inside apply_reverb: received ir_length = 9681
# Saved audio for 000892 to ..\experiments\output_full\output_audio
#
# Processing song: ..\data\raw\fma_small\000\000897.mp3
# Parameters for 000897 saved to ..\experiments\output_full\output_txt\000897_params.txt
# Inside apply_reverb: received ir_length = 7768
# Saved audio for 000897 to ..\experiments\output_full\output_audio
#
# Processing song: ..\data\raw\fma_small\000\000993.mp3
# Parameters for 000993 saved to ..\experiments\output_full\output_txt\000993_params.txt
# Inside apply_reverb: received ir_length = 6333
# Saved audio for 000993 to ..\experiments\output_full\output_audio
#
# Processing song: ..\data\raw\fma_small\000\000995.mp3
# Parameters for 000995 saved to ..\experiments\output_full\output_txt\000995_params.txt
# Inside apply_reverb: received ir_length = 5693
# Saved audio for 000995 to ..\experiments\output_full\output_audio
#
# Processing song: ..\data\raw\fma_small\000\000997.mp3
# Parameters for 000997 saved to ..\experiments\output_full\output_txt\000997_params.txt
# Inside apply_reverb: received ir_length = 6823
# Saved audio for 000997 to ..\experiments\output_full\output_audio
#
# Processing song: ..\data\raw\fma_small\000\000998.mp3
# Parameters for 000998 saved to ..\experiments\output_full\output_txt\000998_params.txt
# Inside apply_reverb: received ir_length = 12214
# Saved audio for 000998 to ..\experiments\output_full\output_audio
#
# Processing song: ..\data\raw\fma_small\001\001039.mp3
# Parameters for 001039 saved to ..\experiments\output_full\output_txt\001039_params.txt
# Inside apply_reverb: received ir_length = 8291
# Saved audio for 001039 to ..\experiments\output_full\output_audio
#
# Processing song: ..\data\raw\fma_small\001\001040.mp3
# Parameters for 001040 saved to ..\experiments\output_full\output_txt\001040_params.txt
# Inside apply_reverb: received ir_length = 8178
# Saved audio for 001040 to ..\experiments\output_full\output_audio
#
# Processing song: ..\data\raw\fma_small\001\001066.mp3
# Parameters for 001066 saved to ..\experiments\output_full\output_txt\001066_params.txt
# Inside apply_reverb: received ir_length = 5403
# Saved audio for 001066 to ..\experiments\output_full\output_audio
#
# Processing song: ..\data\raw\fma_small\001\001069.mp3
# Parameters for 001069 saved to ..\experiments\output_full\output_txt\001069_params.txt
# Inside apply_reverb: received ir_length = 7852
# Saved audio for 001069 to ..\experiments\output_full\output_audio
#
# Processing song: ..\data\raw\fma_small\001\001073.mp3
# Parameters for 001073 saved to ..\experiments\output_full\output_txt\001073_params.txt
# Inside apply_reverb: received ir_length = 10279
# Saved audio for 001073 to ..\experiments\output_full\output_audio
#
# Processing song: ..\data\raw\fma_small\001\001075.mp3
# Parameters for 001075 saved to ..\experiments\output_full\output_txt\001075_params.txt
# Inside apply_reverb: received ir_length = 12978
# Saved audio for 001075 to ..\experiments\output_full\output_audio
#
# Processing song: ..\data\raw\fma_small\001\001082.mp3
# Parameters for 001082 saved to ..\experiments\output_full\output_txt\001082_params.txt
# Inside apply_reverb: received ir_length = 9837
# Saved audio for 001082 to ..\experiments\output_full\output_audio
#
# Processing song: ..\data\raw\fma_small\001\001083.mp3
# Parameters for 001083 saved to ..\experiments\output_full\output_txt\001083_params.txt
# Inside apply_reverb: received ir_length = 4668
# Saved audio for 001083 to ..\experiments\output_full\output_audio
#
# Processing song: ..\data\raw\fma_small\001\001087.mp3
# Parameters for 001087 saved to ..\experiments\output_full\output_txt\001087_params.txt
# Inside apply_reverb: received ir_length = 4749
# Saved audio for 001087 to ..\experiments\output_full\output_audio
#
# Processing song: ..\data\raw\fma_small\001\001102.mp3
# Parameters for 001102 saved to ..\experiments\output_full\output_txt\001102_params.txt
# Inside apply_reverb: received ir_length = 10509
# Saved audio for 001102 to ..\experiments\output_full\output_audio
#
# Processing song: ..\data\raw\fma_small\001\001193.mp3
# Parameters for 001193 saved to ..\experiments\output_full\output_txt\001193_params.txt
# Inside apply_reverb: received ir_length = 8202
# Saved audio for 001193 to ..\experiments\output_full\output_audio
#
# Processing song: ..\data\raw\fma_small\001\001195.mp3
# Parameters for 001195 saved to ..\experiments\output_full\output_txt\001195_params.txt
# Inside apply_reverb: received ir_length = 4864
# Saved audio for 001195 to ..\experiments\output_full\output_audio
#
# Processing song: ..\data\raw\fma_small\001\001196.mp3
# Parameters for 001196 saved to ..\experiments\output_full\output_txt\001196_params.txt
# Inside apply_reverb: received ir_length = 11408
# Saved audio for 001196 to ..\experiments\output_full\output_audio
#
# Processing song: ..\data\raw\fma_small\001\001197.mp3
# Parameters for 001197 saved to ..\experiments\output_full\output_txt\001197_params.txt
# Inside apply_reverb: received ir_length = 12885
# Saved audio for 001197 to ..\experiments\output_full\output_audio
#
# Processing song: ..\data\raw\fma_small\001\001249.mp3
# Parameters for 001249 saved to ..\experiments\output_full\output_txt\001249_params.txt
# Inside apply_reverb: received ir_length = 8986
# Saved audio for 001249 to ..\experiments\output_full\output_audio
#
# Processing song: ..\data\raw\fma_small\001\001259.mp3
# Parameters for 001259 saved to ..\experiments\output_full\output_txt\001259_params.txt
# Inside apply_reverb: received ir_length = 6545
# Saved audio for 001259 to ..\experiments\output_full\output_audio
#
# Processing song: ..\data\raw\fma_small\001\001270.mp3
# Parameters for 001270 saved to ..\experiments\output_full\output_txt\001270_params.txt
# Inside apply_reverb: received ir_length = 7664
# Saved audio for 001270 to ..\experiments\output_full\output_audio
#
# Processing song: ..\data\raw\fma_small\001\001276.mp3
# Parameters for 001276 saved to ..\experiments\output_full\output_txt\001276_params.txt
# Inside apply_reverb: received ir_length = 4972
# Saved audio for 001276 to ..\experiments\output_full\output_audio
#
# Processing song: ..\data\raw\fma_small\001\001277.mp3
# Parameters for 001277 saved to ..\experiments\output_full\output_txt\001277_params.txt
# Inside apply_reverb: received ir_length = 11766
# Saved audio for 001277 to ..\experiments\output_full\output_audio
#
# Processing song: ..\data\raw\fma_small\001\001278.mp3
# Parameters for 001278 saved to ..\experiments\output_full\output_txt\001278_params.txt
# Inside apply_reverb: received ir_length = 10351
# Saved audio for 001278 to ..\experiments\output_full\output_audio
#
# Processing song: ..\data\raw\fma_small\001\001417.mp3
# Parameters for 001417 saved to ..\experiments\output_full\output_txt\001417_params.txt
# Inside apply_reverb: received ir_length = 6952
# Saved audio for 001417 to ..\experiments\output_full\output_audio
#
# Processing song: ..\data\raw\fma_small\001\001427.mp3
# Parameters for 001427 saved to ..\experiments\output_full\output_txt\001427_params.txt
# Inside apply_reverb: received ir_length = 9164
# Saved audio for 001427 to ..\experiments\output_full\output_audio
#
# Processing song: ..\data\raw\fma_small\001\001443.mp3
# Parameters for 001443 saved to ..\experiments\output_full\output_txt\001443_params.txt
# Inside apply_reverb: received ir_length = 9425
# Saved audio for 001443 to ..\experiments\output_full\output_audio
#
# Processing song: ..\data\raw\fma_small\001\001482.mp3
# Parameters for 001482 saved to ..\experiments\output_full\output_txt\001482_params.txt
# Inside apply_reverb: received ir_length = 5105
# Saved audio for 001482 to ..\experiments\output_full\output_audio
#
# Processing song: ..\data\raw\fma_small\001\001510.mp3
# Parameters for 001510 saved to ..\experiments\output_full\output_txt\001510_params.txt
# Inside apply_reverb: received ir_length = 7947
# Saved audio for 001510 to ..\experiments\output_full\output_audio
#
# Processing song: ..\data\raw\fma_small\001\001544.mp3
# Parameters for 001544 saved to ..\experiments\output_full\output_txt\001544_params.txt
# Inside apply_reverb: received ir_length = 6944
# Saved audio for 001544 to ..\experiments\output_full\output_audio
#
# Processing song: ..\data\raw\fma_small\001\001642.mp3
# Parameters for 001642 saved to ..\experiments\output_full\output_txt\001642_params.txt
# Inside apply_reverb: received ir_length = 7595
# Saved audio for 001642 to ..\experiments\output_full\output_audio
#
# Processing song: ..\data\raw\fma_small\001\001644.mp3
# Parameters for 001644 saved to ..\experiments\output_full\output_txt\001644_params.txt
# Inside apply_reverb: received ir_length = 8905
# Saved audio for 001644 to ..\experiments\output_full\output_audio
#
# Processing song: ..\data\raw\fma_small\001\001649.mp3
# Parameters for 001649 saved to ..\experiments\output_full\output_txt\001649_params.txt
# Inside apply_reverb: received ir_length = 8858
# Saved audio for 001649 to ..\experiments\output_full\output_audio
#
# Processing song: ..\data\raw\fma_small\001\001661.mp3
# Parameters for 001661 saved to ..\experiments\output_full\output_txt\001661_params.txt
# Inside apply_reverb: received ir_length = 10930
# Saved audio for 001661 to ..\experiments\output_full\output_audio
#
# Processing song: ..\data\raw\fma_small\001\001663.mp3
# Parameters for 001663 saved to ..\experiments\output_full\output_txt\001663_params.txt
# Inside apply_reverb: received ir_length = 9552
# Saved audio for 001663 to ..\experiments\output_full\output_audio
#
# Processing song: ..\data\raw\fma_small\001\001666.mp3
# Parameters for 001666 saved to ..\experiments\output_full\output_txt\001666_params.txt
# Inside apply_reverb: received ir_length = 8326
# Saved audio for 001666 to ..\experiments\output_full\output_audio
#
# Processing song: ..\data\raw\fma_small\001\001673.mp3
# Parameters for 001673 saved to ..\experiments\output_full\output_txt\001673_params.txt
# Inside apply_reverb: received ir_length = 6422
# Saved audio for 001673 to ..\experiments\output_full\output_audio
#
# Processing song: ..\data\raw\fma_small\001\001680.mp3
# Parameters for 001680 saved to ..\experiments\output_full\output_txt\001680_params.txt
# Inside apply_reverb: received ir_length = 7155
# Saved audio for 001680 to ..\experiments\output_full\output_audio
#
# Processing song: ..\data\raw\fma_small\001\001681.mp3
# Parameters for 001681 saved to ..\experiments\output_full\output_txt\001681_params.txt
# Inside apply_reverb: received ir_length = 5453
# Saved audio for 001681 to ..\experiments\output_full\output_audio
#
# Processing song: ..\data\raw\fma_small\001\001682.mp3
# Parameters for 001682 saved to ..\experiments\output_full\output_txt\001682_params.txt
# Inside apply_reverb: received ir_length = 6691
# Saved audio for 001682 to ..\experiments\output_full\output_audio
#
# Processing song: ..\data\raw\fma_small\001\001683.mp3
# Parameters for 001683 saved to ..\experiments\output_full\output_txt\001683_params.txt
# Inside apply_reverb: received ir_length = 6004
# Saved audio for 001683 to ..\experiments\output_full\output_audio
#
# Processing song: ..\data\raw\fma_small\001\001684.mp3
# Parameters for 001684 saved to ..\experiments\output_full\output_txt\001684_params.txt
# Inside apply_reverb: received ir_length = 4930
# Saved audio for 001684 to ..\experiments\output_full\output_audio
#
# Processing song: ..\data\raw\fma_small\001\001685.mp3
# Parameters for 001685 saved to ..\experiments\output_full\output_txt\001685_params.txt
# Inside apply_reverb: received ir_length = 13156
# Saved audio for 001685 to ..\experiments\output_full\output_audio
#
# Processing song: ..\data\raw\fma_small\001\001686.mp3
# Parameters for 001686 saved to ..\experiments\output_full\output_txt\001686_params.txt
# Inside apply_reverb: received ir_length = 11718
# Saved audio for 001686 to ..\experiments\output_full\output_audio
#
# Processing song: ..\data\raw\fma_small\001\001687.mp3
# Parameters for 001687 saved to ..\experiments\output_full\output_txt\001687_params.txt
# Inside apply_reverb: received ir_length = 6982
# Saved audio for 001687 to ..\experiments\output_full\output_audio
#
# Processing song: ..\data\raw\fma_small\001\001688.mp3
# Parameters for 001688 saved to ..\experiments\output_full\output_txt\001688_params.txt
# Inside apply_reverb: received ir_length = 11402
# Saved audio for 001688 to ..\experiments\output_full\output_audio
#
# Processing song: ..\data\raw\fma_small\001\001689.mp3
# Parameters for 001689 saved to ..\experiments\output_full\output_txt\001689_params.txt
# Inside apply_reverb: received ir_length = 10622
# Saved audio for 001689 to ..\experiments\output_full\output_audio
#
# Processing song: ..\data\raw\fma_small\001\001701.mp3
# Parameters for 001701 saved to ..\experiments\output_full\output_txt\001701_params.txt
# Inside apply_reverb: received ir_length = 4468
# Saved audio for 001701 to ..\experiments\output_full\output_audio
#
# Processing song: ..\data\raw\fma_small\001\001702.mp3
# Parameters for 001702 saved to ..\experiments\output_full\output_txt\001702_params.txt
# Inside apply_reverb: received ir_length = 12452
# Saved audio for 001702 to ..\experiments\output_full\output_audio
#
# Processing song: ..\data\raw\fma_small\001\001703.mp3
# Parameters for 001703 saved to ..\experiments\output_full\output_txt\001703_params.txt
# Inside apply_reverb: received ir_length = 11410
# Saved audio for 001703 to ..\experiments\output_full\output_audio
#
# Processing song: ..\data\raw\fma_small\001\001704.mp3
# Parameters for 001704 saved to ..\experiments\output_full\output_txt\001704_params.txt
# Inside apply_reverb: received ir_length = 6459
# Saved audio for 001704 to ..\experiments\output_full\output_audio
#
# Processing song: ..\data\raw\fma_small\001\001706.mp3
# Parameters for 001706 saved to ..\experiments\output_full\output_txt\001706_params.txt
# Inside apply_reverb: received ir_length = 7330
# Saved audio for 001706 to ..\experiments\output_full\output_audio
#
# Processing song: ..\data\raw\fma_small\001\001720.mp3
# Parameters for 001720 saved to ..\experiments\output_full\output_txt\001720_params.txt
# Inside apply_reverb: received ir_length = 12311
# Saved audio for 001720 to ..\experiments\output_full\output_audio
#
# Processing song: ..\data\raw\fma_small\001\001732.mp3
# Parameters for 001732 saved to ..\experiments\output_full\output_txt\001732_params.txt
# Inside apply_reverb: received ir_length = 10869
# Saved audio for 001732 to ..\experiments\output_full\output_audio
#
# Processing song: ..\data\raw\fma_small\001\001733.mp3
# Parameters for 001733 saved to ..\experiments\output_full\output_txt\001733_params.txt
# Inside apply_reverb: received ir_length = 4666
# Saved audio for 001733 to ..\experiments\output_full\output_audio
#
# Processing song: ..\data\raw\fma_small\001\001735.mp3
# Parameters for 001735 saved to ..\experiments\output_full\output_txt\001735_params.txt
# Inside apply_reverb: received ir_length = 5158
# Saved audio for 001735 to ..\experiments\output_full\output_audio
#
# Processing song: ..\data\raw\fma_small\001\001736.mp3
# Parameters for 001736 saved to ..\experiments\output_full\output_txt\001736_params.txt
# Inside apply_reverb: received ir_length = 6218
# Saved audio for 001736 to ..\experiments\output_full\output_audio
#
# Processing song: ..\data\raw\fma_small\001\001883.mp3
# Parameters for 001883 saved to ..\experiments\output_full\output_txt\001883_params.txt
# Inside apply_reverb: received ir_length = 6268
# Saved audio for 001883 to ..\experiments\output_full\output_audio
#
# Processing song: ..\data\raw\fma_small\001\001891.mp3
# Parameters for 001891 saved to ..\experiments\output_full\output_txt\001891_params.txt
# Inside apply_reverb: received ir_length = 5464
# Saved audio for 001891 to ..\experiments\output_full\output_audio
#
# Processing song: ..\data\raw\fma_small\001\001893.mp3
# Parameters for 001893 saved to ..\experiments\output_full\output_txt\001893_params.txt
# Inside apply_reverb: received ir_length = 8672
# Saved audio for 001893 to ..\experiments\output_full\output_audio
#
# Processing song: ..\data\raw\fma_small\001\001924.mp3
# Parameters for 001924 saved to ..\experiments\output_full\output_txt\001924_params.txt
# Inside apply_reverb: received ir_length = 8353
# Saved audio for 001924 to ..\experiments\output_full\output_audio
#
# Processing song: ..\data\raw\fma_small\001\001925.mp3
# Parameters for 001925 saved to ..\experiments\output_full\output_txt\001925_params.txt
# Inside apply_reverb: received ir_length = 9031
# Saved audio for 001925 to ..\experiments\output_full\output_audio
#
# Processing song: ..\data\raw\fma_small\001\001929.mp3
# Parameters for 001929 saved to ..\experiments\output_full\output_txt\001929_params.txt
# Inside apply_reverb: received ir_length = 8299
# Saved audio for 001929 to ..\experiments\output_full\output_audio
#
# Processing song: ..\data\raw\fma_small\001\001930.mp3
# Parameters for 001930 saved to ..\experiments\output_full\output_txt\001930_params.txt
# Inside apply_reverb: received ir_length = 6814
# Saved audio for 001930 to ..\experiments\output_full\output_audio
#
# Processing song: ..\data\raw\fma_small\002\002012.mp3
# Parameters for 002012 saved to ..\experiments\output_full\output_txt\002012_params.txt
# Inside apply_reverb: received ir_length = 4504
# Saved audio for 002012 to ..\experiments\output_full\output_audio
#
# Processing song: ..\data\raw\fma_small\002\002096.mp3
# Parameters for 002096 saved to ..\experiments\output_full\output_txt\002096_params.txt
# Inside apply_reverb: received ir_length = 10970
# Saved audio for 002096 to ..\experiments\output_full\output_audio
#
# Processing song: ..\data\raw\fma_small\002\002097.mp3
# Parameters for 002097 saved to ..\experiments\output_full\output_txt\002097_params.txt
# Inside apply_reverb: received ir_length = 7709
# Saved audio for 002097 to ..\experiments\output_full\output_audio
#
# Processing song: ..\data\raw\fma_small\002\002099.mp3
# Parameters for 002099 saved to ..\experiments\output_full\output_txt\002099_params.txt
# Inside apply_reverb: received ir_length = 7895
# Saved audio for 002099 to ..\experiments\output_full\output_audio
#
# Processing song: ..\data\raw\fma_small\003\003263.mp3
# Parameters for 003263 saved to ..\experiments\output_full\output_txt\003263_params.txt
# Inside apply_reverb: received ir_length = 11245
# Saved audio for 003263 to ..\experiments\output_full\output_audio
#
# Processing song: ..\data\raw\fma_small\003\003264.mp3
# Parameters for 003264 saved to ..\experiments\output_full\output_txt\003264_params.txt
# Inside apply_reverb: received ir_length = 7655
# Saved audio for 003264 to ..\experiments\output_full\output_audio
#
# Processing song: ..\data\raw\fma_small\003\003265.mp3
# Parameters for 003265 saved to ..\experiments\output_full\output_txt\003265_params.txt
# Inside apply_reverb: received ir_length = 12798
# Saved audio for 003265 to ..\experiments\output_full\output_audio
#
# Processing song: ..\data\raw\fma_small\003\003266.mp3
# Parameters for 003266 saved to ..\experiments\output_full\output_txt\003266_params.txt
# Inside apply_reverb: received ir_length = 6078
# Saved audio for 003266 to ..\experiments\output_full\output_audio
#
# Processing song: ..\data\raw\fma_small\003\003270.mp3
# Parameters for 003270 saved to ..\experiments\output_full\output_txt\003270_params.txt
# Inside apply_reverb: received ir_length = 6599
# Saved audio for 003270 to ..\experiments\output_full\output_audio
#
# Processing song: ..\data\raw\fma_small\003\003271.mp3
# Parameters for 003271 saved to ..\experiments\output_full\output_txt\003271_params.txt
# Inside apply_reverb: received ir_length = 7185
# Saved audio for 003271 to ..\experiments\output_full\output_audio
#
# Processing song: ..\data\raw\fma_small\003\003272.mp3
# Parameters for 003272 saved to ..\experiments\output_full\output_txt\003272_params.txt
# Inside apply_reverb: received ir_length = 8276
# Saved audio for 003272 to ..\experiments\output_full\output_audio
#
# Processing song: ..\data\raw\fma_small\003\003273.mp3
# Parameters for 003273 saved to ..\experiments\output_full\output_txt\003273_params.txt
# Inside apply_reverb: received ir_length = 5616
# Saved audio for 003273 to ..\experiments\output_full\output_audio
#
# Processing song: ..\data\raw\fma_small\003\003274.mp3
# Parameters for 003274 saved to ..\experiments\output_full\output_txt\003274_params.txt
# Inside apply_reverb: received ir_length = 9057
# Saved audio for 003274 to ..\experiments\output_full\output_audio
#
# Processing song: ..\data\raw\fma_small\003\003492.mp3
# Parameters for 003492 saved to ..\experiments\output_full\output_txt\003492_params.txt
# Inside apply_reverb: received ir_length = 11269
# Saved audio for 003492 to ..\experiments\output_full\output_audio
#
# Processing song: ..\data\raw\fma_small\003\003532.mp3
# Parameters for 003532 saved to ..\experiments\output_full\output_txt\003532_params.txt
# Inside apply_reverb: received ir_length = 10136
# Saved audio for 003532 to ..\experiments\output_full\output_audio
#
# Processing song: ..\data\raw\fma_small\003\003533.mp3
# Parameters for 003533 saved to ..\experiments\output_full\output_txt\003533_params.txt
# Inside apply_reverb: received ir_length = 7412
# Saved audio for 003533 to ..\experiments\output_full\output_audio
#
# Processing song: ..\data\raw\fma_small\003\003534.mp3
# Parameters for 003534 saved to ..\experiments\output_full\output_txt\003534_params.txt
# Inside apply_reverb: received ir_length = 11482
# Saved audio for 003534 to ..\experiments\output_full\output_audio
#
# Processing song: ..\data\raw\fma_small\003\003535.mp3
# Parameters for 003535 saved to ..\experiments\output_full\output_txt\003535_params.txt
# Inside apply_reverb: received ir_length = 7383
# Saved audio for 003535 to ..\experiments\output_full\output_audio
#
# Processing song: ..\data\raw\fma_small\003\003537.mp3
# Parameters for 003537 saved to ..\experiments\output_full\output_txt\003537_params.txt
# Inside apply_reverb: received ir_length = 8159
# Saved audio for 003537 to ..\experiments\output_full\output_audio
#
# Processing song: ..\data\raw\fma_small\003\003538.mp3
# Parameters for 003538 saved to ..\experiments\output_full\output_txt\003538_params.txt
# Inside apply_reverb: received ir_length = 10468
# Saved audio for 003538 to ..\experiments\output_full\output_audio
#
# Processing song: ..\data\raw\fma_small\003\003573.mp3
# Parameters for 003573 saved to ..\experiments\output_full\output_txt\003573_params.txt
# Inside apply_reverb: received ir_length = 12153
# Saved audio for 003573 to ..\experiments\output_full\output_audio
#
# Processing song: ..\data\raw\fma_small\003\003598.mp3
# Parameters for 003598 saved to ..\experiments\output_full\output_txt\003598_params.txt
# Inside apply_reverb: received ir_length = 12930
# Saved audio for 003598 to ..\experiments\output_full\output_audio
#
# Processing song: ..\data\raw\fma_small\003\003624.mp3
# Parameters for 003624 saved to ..\experiments\output_full\output_txt\003624_params.txt
# Inside apply_reverb: received ir_length = 10923
# Saved audio for 003624 to ..\experiments\output_full\output_audio
#
# Processing song: ..\data\raw\fma_small\003\003707.mp3
# Parameters for 003707 saved to ..\experiments\output_full\output_txt\003707_params.txt
# Inside apply_reverb: received ir_length = 6533
# Saved audio for 003707 to ..\experiments\output_full\output_audio
#
# Processing song: ..\data\raw\fma_small\003\003708.mp3
# Parameters for 003708 saved to ..\experiments\output_full\output_txt\003708_params.txt
# Inside apply_reverb: received ir_length = 10222
# Saved audio for 003708 to ..\experiments\output_full\output_audio
#
# Processing song: ..\data\raw\fma_small\003\003720.mp3
# Parameters for 003720 saved to ..\experiments\output_full\output_txt\003720_params.txt
# Inside apply_reverb: received ir_length = 4479
# Saved audio for 003720 to ..\experiments\output_full\output_audio
#
# Processing song: ..\data\raw\fma_small\003\003721.mp3
# Parameters for 003721 saved to ..\experiments\output_full\output_txt\003721_params.txt
# Inside apply_reverb: received ir_length = 12815
# Saved audio for 003721 to ..\experiments\output_full\output_audio
#
# Processing song: ..\data\raw\fma_small\003\003722.mp3
# Parameters for 003722 saved to ..\experiments\output_full\output_txt\003722_params.txt
# Inside apply_reverb: received ir_length = 8863
# Saved audio for 003722 to ..\experiments\output_full\output_audio
#
# Processing song: ..\data\raw\fma_small\003\003724.mp3
# Parameters for 003724 saved to ..\experiments\output_full\output_txt\003724_params.txt
# Inside apply_reverb: received ir_length = 13168
# Saved audio for 003724 to ..\experiments\output_full\output_audio
#
# Processing song: ..\data\raw\fma_small\003\003725.mp3
# Parameters for 003725 saved to ..\experiments\output_full\output_txt\003725_params.txt
# Inside apply_reverb: received ir_length = 13110
# Saved audio for 003725 to ..\experiments\output_full\output_audio
#
# Processing song: ..\data\raw\fma_small\003\003761.mp3
# Parameters for 003761 saved to ..\experiments\output_full\output_txt\003761_params.txt
# Inside apply_reverb: received ir_length = 5602
# Saved audio for 003761 to ..\experiments\output_full\output_audio
#
# Processing song: ..\data\raw\fma_small\003\003762.mp3
# Parameters for 003762 saved to ..\experiments\output_full\output_txt\003762_params.txt
# Inside apply_reverb: received ir_length = 12758
# Saved audio for 003762 to ..\experiments\output_full\output_audio
#
# Processing song: ..\data\raw\fma_small\003\003763.mp3
# Parameters for 003763 saved to ..\experiments\output_full\output_txt\003763_params.txt
# Inside apply_reverb: received ir_length = 11693
# Saved audio for 003763 to ..\experiments\output_full\output_audio
#
# Processing song: ..\data\raw\fma_small\003\003765.mp3
# Parameters for 003765 saved to ..\experiments\output_full\output_txt\003765_params.txt
# Inside apply_reverb: received ir_length = 7610
# Saved audio for 003765 to ..\experiments\output_full\output_audio
#
# Processing song: ..\data\raw\fma_small\003\003766.mp3
# Parameters for 003766 saved to ..\experiments\output_full\output_txt\003766_params.txt
# Inside apply_reverb: received ir_length = 6784
# Saved audio for 003766 to ..\experiments\output_full\output_audio
#
# Processing song: ..\data\raw\fma_small\003\003775.mp3
# Parameters for 003775 saved to ..\experiments\output_full\output_txt\003775_params.txt
# Inside apply_reverb: received ir_length = 4806
# Saved audio for 003775 to ..\experiments\output_full\output_audio
#
# Processing song: ..\data\raw\fma_small\003\003776.mp3
# Parameters for 003776 saved to ..\experiments\output_full\output_txt\003776_params.txt
# Inside apply_reverb: received ir_length = 8254
# Saved audio for 003776 to ..\experiments\output_full\output_audio
#
# Processing song: ..\data\raw\fma_small\003\003777.mp3
# Parameters for 003777 saved to ..\experiments\output_full\output_txt\003777_params.txt
# Inside apply_reverb: received ir_length = 10188
# Saved audio for 003777 to ..\experiments\output_full\output_audio
#
# Processing song: ..\data\raw\fma_small\003\003778.mp3
# Parameters for 003778 saved to ..\experiments\output_full\output_txt\003778_params.txt
# Inside apply_reverb: received ir_length = 9940
# Saved audio for 003778 to ..\experiments\output_full\output_audio
#
# Processing song: ..\data\raw\fma_small\003\003779.mp3
# Parameters for 003779 saved to ..\experiments\output_full\output_txt\003779_params.txt
# Inside apply_reverb: received ir_length = 6971
# Saved audio for 003779 to ..\experiments\output_full\output_audio
#
# Processing song: ..\data\raw\fma_small\003\003832.mp3
# Parameters for 003832 saved to ..\experiments\output_full\output_txt\003832_params.txt
# Inside apply_reverb: received ir_length = 11684
# Saved audio for 003832 to ..\experiments\output_full\output_audio
#
# Processing song: ..\data\raw\fma_small\003\003833.mp3
# Parameters for 003833 saved to ..\experiments\output_full\output_txt\003833_params.txt
# Inside apply_reverb: received ir_length = 7317
# Saved audio for 003833 to ..\experiments\output_full\output_audio
#
# Processing song: ..\data\raw\fma_small\003\003840.mp3
# Parameters for 003840 saved to ..\experiments\output_full\output_txt\003840_params.txt
# Inside apply_reverb: received ir_length = 12688
# Saved audio for 003840 to ..\experiments\output_full\output_audio
#
# Processing song: ..\data\raw\fma_small\003\003880.mp3
# Parameters for 003880 saved to ..\experiments\output_full\output_txt\003880_params.txt
# Inside apply_reverb: received ir_length = 6078
# Saved audio for 003880 to ..\experiments\output_full\output_audio
#
# Processing song: ..\data\raw\fma_small\003\003895.mp3
# Parameters for 003895 saved to ..\experiments\output_full\output_txt\003895_params.txt
# Inside apply_reverb: received ir_length = 7828
# Saved audio for 003895 to ..\experiments\output_full\output_audio
#
# Processing song: ..\data\raw\fma_small\003\003896.mp3
# Parameters for 003896 saved to ..\experiments\output_full\output_txt\003896_params.txt
# Inside apply_reverb: received ir_length = 9612
# Saved audio for 003896 to ..\experiments\output_full\output_audio
#
# Processing song: ..\data\raw\fma_small\003\003904.mp3
# Parameters for 003904 saved to ..\experiments\output_full\output_txt\003904_params.txt
# Inside apply_reverb: received ir_length = 7025
# Saved audio for 003904 to ..\experiments\output_full\output_audio
#
# Processing song: ..\data\raw\fma_small\003\003905.mp3
# Parameters for 003905 saved to ..\experiments\output_full\output_txt\003905_params.txt
# Inside apply_reverb: received ir_length = 8644
# Saved audio for 003905 to ..\experiments\output_full\output_audio
#
# Processing song: ..\data\raw\fma_small\003\003906.mp3
# Parameters for 003906 saved to ..\experiments\output_full\output_txt\003906_params.txt
# Inside apply_reverb: received ir_length = 10990
# Saved audio for 003906 to ..\experiments\output_full\output_audio
#
# Processing song: ..\data\raw\fma_small\003\003908.mp3
# Parameters for 003908 saved to ..\experiments\output_full\output_txt\003908_params.txt
# Inside apply_reverb: received ir_length = 9009
# Saved audio for 003908 to ..\experiments\output_full\output_audio
#
# Processing song: ..\data\raw\fma_small\003\003909.mp3
# Parameters for 003909 saved to ..\experiments\output_full\output_txt\003909_params.txt
# Inside apply_reverb: received ir_length = 11755
# Saved audio for 003909 to ..\experiments\output_full\output_audio
#
# Processing song: ..\data\raw\fma_small\003\003910.mp3
# Parameters for 003910 saved to ..\experiments\output_full\output_txt\003910_params.txt
# Inside apply_reverb: received ir_length = 4474
# Saved audio for 003910 to ..\experiments\output_full\output_audio
#
# Processing song: ..\data\raw\fma_small\003\003911.mp3
# Parameters for 003911 saved to ..\experiments\output_full\output_txt\003911_params.txt
# Inside apply_reverb: received ir_length = 6678
# Saved audio for 003911 to ..\experiments\output_full\output_audio
#
# Processing song: ..\data\raw\fma_small\003\003912.mp3
# Parameters for 003912 saved to ..\experiments\output_full\output_txt\003912_params.txt
# Inside apply_reverb: received ir_length = 10664
# Saved audio for 003912 to ..\experiments\output_full\output_audio
#
# Processing song: ..\data\raw\fma_small\003\003913.mp3
# Parameters for 003913 saved to ..\experiments\output_full\output_txt\003913_params.txt
# Inside apply_reverb: received ir_length = 8748
# Saved audio for 003913 to ..\experiments\output_full\output_audio
#
# Processing song: ..\data\raw\fma_small\003\003920.mp3
# Parameters for 003920 saved to ..\experiments\output_full\output_txt\003920_params.txt
# Inside apply_reverb: received ir_length = 12601
# Saved audio for 003920 to ..\experiments\output_full\output_audio
#
# Processing song: ..\data\raw\fma_small\003\003921.mp3
# Parameters for 003921 saved to ..\experiments\output_full\output_txt\003921_params.txt
# Inside apply_reverb: received ir_length = 11616
# Saved audio for 003921 to ..\experiments\output_full\output_audio
#
# Processing song: ..\data\raw\fma_small\003\003950.mp3
# Parameters for 003950 saved to ..\experiments\output_full\output_txt\003950_params.txt
# Inside apply_reverb: received ir_length = 9426
# Saved audio for 003950 to ..\experiments\output_full\output_audio
#
# Processing song: ..\data\raw\fma_small\004\004013.mp3
# Parameters for 004013 saved to ..\experiments\output_full\output_txt\004013_params.txt
# Inside apply_reverb: received ir_length = 8067
# Saved audio for 004013 to ..\experiments\output_full\output_audio
#
# Processing song: ..\data\raw\fma_small\004\004017.mp3
# Parameters for 004017 saved to ..\experiments\output_full\output_txt\004017_params.txt
# Inside apply_reverb: received ir_length = 6305
# Saved audio for 004017 to ..\experiments\output_full\output_audio
#
# Processing song: ..\data\raw\fma_small\004\004022.mp3
# Parameters for 004022 saved to ..\experiments\output_full\output_txt\004022_params.txt
# Inside apply_reverb: received ir_length = 12052
# Saved audio for 004022 to ..\experiments\output_full\output_audio
#
# Processing song: ..\data\raw\fma_small\004\004037.mp3
# Parameters for 004037 saved to ..\experiments\output_full\output_txt\004037_params.txt
# Inside apply_reverb: received ir_length = 9804
# Saved audio for 004037 to ..\experiments\output_full\output_audio
#
# Processing song: ..\data\raw\fma_small\004\004066.mp3
# Parameters for 004066 saved to ..\experiments\output_full\output_txt\004066_params.txt
# Inside apply_reverb: received ir_length = 5181
# Saved audio for 004066 to ..\experiments\output_full\output_audio
#
# Processing song: ..\data\raw\fma_small\004\004067.mp3
# Parameters for 004067 saved to ..\experiments\output_full\output_txt\004067_params.txt
# Inside apply_reverb: received ir_length = 13032
# Saved audio for 004067 to ..\experiments\output_full\output_audio
#
# Processing song: ..\data\raw\fma_small\004\004068.mp3
# Parameters for 004068 saved to ..\experiments\output_full\output_txt\004068_params.txt
# Inside apply_reverb: received ir_length = 5270
# Saved audio for 004068 to ..\experiments\output_full\output_audio
#
# Processing song: ..\data\raw\fma_small\004\004069.mp3
# Parameters for 004069 saved to ..\experiments\output_full\output_txt\004069_params.txt
# Inside apply_reverb: received ir_length = 8625
# ...
# Inside apply_reverb: received ir_length = 7654
# Saved audio for 006519 to ..\experiments\output_full\output_audio
#
# Processing song: ..\data\raw\fma_small\006\006603.mp3
# Parameters for 006603 saved to ..\experiments\output_full\output_txt\006603_params.txt
# Inside apply_reverb: received ir_length = 9156
# Saved audio for 006603 to ..\experiments\output_full\output_audio
#
# Processing song: ..\data\raw\fma_small\006\006605.mp3
# Parameters for 006605 saved to ..\experiments\output_full\output_txt\006605_params.txt
# Inside apply_reverb: received ir_length = 11506
# Saved audio for 006605 to ..\experiments\output_full\output_audio
#
# Processing song: ..\data\raw\fma_small\006\006606.mp3
# Parameters for 006606 saved to ..\experiments\output_full\output_txt\006606_params.txt
# Inside apply_reverb: received ir_length = 12334
# Saved audio for 006606 to ..\experiments\output_full\output_audio
#
# Processing song: ..\data\raw\fma_small\006\006607.mp3
# Parameters for 006607 saved to ..\experiments\output_full\output_txt\006607_params.txt
# Inside apply_reverb: received ir_length = 7976
# Saved audio for 006607 to ..\experiments\output_full\output_audio
#
# Processing song: ..\data\raw\fma_small\006\006608.mp3
# Parameters for 006608 saved to ..\experiments\output_full\output_txt\006608_params.txt
# Inside apply_reverb: received ir_length = 10477
# Saved audio for 006608 to ..\experiments\output_full\output_audio
#
# Processing song: ..\data\raw\fma_small\006\006609.mp3
# Parameters for 006609 saved to ..\experiments\output_full\output_txt\006609_params.txt
# Inside apply_reverb: received ir_length = 7148
# Saved audio for 006609 to ..\experiments\output_full\output_audio
#
# Processing song: ..\data\raw\fma_small\006\006610.mp3
# Parameters for 006610 saved to ..\experiments\output_full\output_txt\006610_params.txt
# Inside apply_reverb: received ir_length = 7377
# Saved audio for 006610 to ..\experiments\output_full\output_audio
#
# Processing song: ..\data\raw\fma_small\006\006611.mp3
# Parameters for 006611 saved to ..\experiments\output_full\output_txt\006611_params.txt
# Inside apply_reverb: received ir_length = 12110
# Saved audio for 006611 to ..\experiments\output_full\output_audio
#
# Processing song: ..\data\raw\fma_small\006\006674.mp3
# Parameters for 006674 saved to ..\experiments\output_full\output_txt\006674_params.txt
# Inside apply_reverb: received ir_length = 4601
# Saved audio for 006674 to ..\experiments\output_full\output_audio
#
# Processing song: ..\data\raw\fma_small\006\006675.mp3
# Parameters for 006675 saved to ..\experiments\output_full\output_txt\006675_params.txt
# Inside apply_reverb: received ir_length = 7561
# Saved audio for 006675 to ..\experiments\output_full\output_audio
#
# Processing song: ..\data\raw\fma_small\006\006677.mp3
# Parameters for 006677 saved to ..\experiments\output_full\output_txt\006677_params.txt
# Inside apply_reverb: received ir_length = 12771
# Saved audio for 006677 to ..\experiments\output_full\output_audio
#
# Processing song: ..\data\raw\fma_small\006\006679.mp3
# Parameters for 006679 saved to ..\experiments\output_full\output_txt\006679_params.txt
# Inside apply_reverb: received ir_length = 12235
# Saved audio for 006679 to ..\experiments\output_full\output_audio
#
# Processing song: ..\data\raw\fma_small\006\006680.mp3
# Parameters for 006680 saved to ..\experiments\output_full\output_txt\006680_params.txt
# Inside apply_reverb: received ir_length = 9106
# Saved audio for 006680 to ..\experiments\output_full\output_audio
#
# Processing song: ..\data\raw\fma_small\006\006684.mp3
# Parameters for 006684 saved to ..\experiments\output_full\output_txt\006684_params.txt
# Inside apply_reverb: received ir_length = 12462
# Saved audio for 006684 to ..\experiments\output_full\output_audio
#
# Processing song: ..\data\raw\fma_small\006\006762.mp3
# Parameters for 006762 saved to ..\experiments\output_full\output_txt\006762_params.txt
# Inside apply_reverb: received ir_length = 5474
# Saved audio for 006762 to ..\experiments\output_full\output_audio
#
# Processing song: ..\data\raw\fma_small\006\006776.mp3
# Parameters for 006776 saved to ..\experiments\output_full\output_txt\006776_params.txt
# Inside apply_reverb: received ir_length = 7918
# Saved audio for 006776 to ..\experiments\output_full\output_audio
#
# Processing song: ..\data\raw\fma_small\006\006778.mp3
# Parameters for 006778 saved to ..\experiments\output_full\output_txt\006778_params.txt
# Inside apply_reverb: received ir_length = 7879
# Saved audio for 006778 to ..\experiments\output_full\output_audio
#
# Processing song: ..\data\raw\fma_small\006\006779.mp3
# Parameters for 006779 saved to ..\experiments\output_full\output_txt\006779_params.txt
# Inside apply_reverb: received ir_length = 9280
# Saved audio for 006779 to ..\experiments\output_full\output_audio
#
# Processing song: ..\data\raw\fma_small\006\006782.mp3
# Parameters for 006782 saved to ..\experiments\output_full\output_txt\006782_params.txt
# Inside apply_reverb: received ir_length = 10355
# Saved audio for 006782 to ..\experiments\output_full\output_audio
#
# Processing song: ..\data\raw\fma_small\006\006783.mp3
# Parameters for 006783 saved to ..\experiments\output_full\output_txt\006783_params.txt
# Inside apply_reverb: received ir_length = 10995
# Saved audio for 006783 to ..\experiments\output_full\output_audio
#
# Processing song: ..\data\raw\fma_small\006\006788.mp3
# Parameters for 006788 saved to ..\experiments\output_full\output_txt\006788_params.txt
# Inside apply_reverb: received ir_length = 10598
# Saved audio for 006788 to ..\experiments\output_full\output_audio
#
# Processing song: ..\data\raw\fma_small\006\006802.mp3
# Parameters for 006802 saved to ..\experiments\output_full\output_txt\006802_params.txt
# Inside apply_reverb: received ir_length = 12541
# Saved audio for 006802 to ..\experiments\output_full\output_audio
#
# Processing song: ..\data\raw\fma_small\006\006803.mp3
# Parameters for 006803 saved to ..\experiments\output_full\output_txt\006803_params.txt
# Inside apply_reverb: received ir_length = 11296
# Saved audio for 006803 to ..\experiments\output_full\output_audio
#
# Processing song: ..\data\raw\fma_small\006\006854.mp3
# Parameters for 006854 saved to ..\experiments\output_full\output_txt\006854_params.txt
# Inside apply_reverb: received ir_length = 11527
# Saved audio for 006854 to ..\experiments\output_full\output_audio
#
# Processing song: ..\data\raw\fma_small\006\006855.mp3
# Parameters for 006855 saved to ..\experiments\output_full\output_txt\006855_params.txt
# Inside apply_reverb: received ir_length = 9175
# Saved audio for 006855 to ..\experiments\output_full\output_audio
#
# Processing song: ..\data\raw\fma_small\006\006856.mp3
# Parameters for 006856 saved to ..\experiments\output_full\output_txt\006856_params.txt
# Inside apply_reverb: received ir_length = 8672
# Saved audio for 006856 to ..\experiments\output_full\output_audio
#
# Processing song: ..\data\raw\fma_small\006\006857.mp3
# Parameters for 006857 saved to ..\experiments\output_full\output_txt\006857_params.txt
# Inside apply_reverb: received ir_length = 8814
# Saved audio for 006857 to ..\experiments\output_full\output_audio
#
# Processing song: ..\data\raw\fma_small\007\007011.mp3
# Parameters for 007011 saved to ..\experiments\output_full\output_txt\007011_params.txt
# Inside apply_reverb: received ir_length = 11869
# Saved audio for 007011 to ..\experiments\output_full\output_audio
#
# Processing song: ..\data\raw\fma_small\007\007373.mp3
# Parameters for 007373 saved to ..\experiments\output_full\output_txt\007373_params.txt
# Inside apply_reverb: received ir_length = 9678
# Saved audio for 007373 to ..\experiments\output_full\output_audio
#
# Processing song: ..\data\raw\fma_small\007\007374.mp3
# Parameters for 007374 saved to ..\experiments\output_full\output_txt\007374_params.txt
# Inside apply_reverb: received ir_length = 10308
# Saved audio for 007374 to ..\experiments\output_full\output_audio
#
# Processing song: ..\data\raw\fma_small\007\007375.mp3
# Parameters for 007375 saved to ..\experiments\output_full\output_txt\007375_params.txt
# Inside apply_reverb: received ir_length = 6965
# Saved audio for 007375 to ..\experiments\output_full\output_audio
#
# Processing song: ..\data\raw\fma_small\007\007376.mp3
# Parameters for 007376 saved to ..\experiments\output_full\output_txt\007376_params.txt
# Inside apply_reverb: received ir_length = 7398
# Saved audio for 007376 to ..\experiments\output_full\output_audio
#
# Processing song: ..\data\raw\fma_small\007\007377.mp3
# Parameters for 007377 saved to ..\experiments\output_full\output_txt\007377_params.txt
# Inside apply_reverb: received ir_length = 9353
# Saved audio for 007377 to ..\experiments\output_full\output_audio
#
# Processing song: ..\data\raw\fma_small\007\007378.mp3
# Parameters for 007378 saved to ..\experiments\output_full\output_txt\007378_params.txt
# Inside apply_reverb: received ir_length = 10732
# Saved audio for 007378 to ..\experiments\output_full\output_audio
#
# Processing song: ..\data\raw\fma_small\007\007379.mp3
# Parameters for 007379 saved to ..\experiments\output_full\output_txt\007379_params.txt
# Inside apply_reverb: received ir_length = 10213
# Saved audio for 007379 to ..\experiments\output_full\output_audio
#
# Processing song: ..\data\raw\fma_small\007\007381.mp3
# Parameters for 007381 saved to ..\experiments\output_full\output_txt\007381_params.txt
# Inside apply_reverb: received ir_length = 7233
# Saved audio for 007381 to ..\experiments\output_full\output_audio
#
# Processing song: ..\data\raw\fma_small\007\007383.mp3
# Parameters for 007383 saved to ..\experiments\output_full\output_txt\007383_params.txt
# Inside apply_reverb: received ir_length = 8011
# Saved audio for 007383 to ..\experiments\output_full\output_audio
#
# Processing song: ..\data\raw\fma_small\007\007385.mp3
# Parameters for 007385 saved to ..\experiments\output_full\output_txt\007385_params.txt
# Inside apply_reverb: received ir_length = 12200
# Saved audio for 007385 to ..\experiments\output_full\output_audio
#
# Processing song: ..\data\raw\fma_small\007\007386.mp3
# Parameters for 007386 saved to ..\experiments\output_full\output_txt\007386_params.txt
# Inside apply_reverb: received ir_length = 10753
# Saved audio for 007386 to ..\experiments\output_full\output_audio
#
# Processing song: ..\data\raw\fma_small\007\007388.mp3
# Parameters for 007388 saved to ..\experiments\output_full\output_txt\007388_params.txt
# Inside apply_reverb: received ir_length = 10728
# Saved audio for 007388 to ..\experiments\output_full\output_audio
#
# Processing song: ..\data\raw\fma_small\007\007391.mp3
# Parameters for 007391 saved to ..\experiments\output_full\output_txt\007391_params.txt
# Inside apply_reverb: received ir_length = 12086
# Saved audio for 007391 to ..\experiments\output_full\output_audio
#
# Processing song: ..\data\raw\fma_small\007\007393.mp3
# Parameters for 007393 saved to ..\experiments\output_full\output_txt\007393_params.txt
# Inside apply_reverb: received ir_length = 6492
# Saved audio for 007393 to ..\experiments\output_full\output_audio
#
# Processing song: ..\data\raw\fma_small\007\007481.mp3
# Parameters for 007481 saved to ..\experiments\output_full\output_txt\007481_params.txt
# Inside apply_reverb: received ir_length = 10536
# Saved audio for 007481 to ..\experiments\output_full\output_audio
#
# Processing song: ..\data\raw\fma_small\007\007482.mp3
# Parameters for 007482 saved to ..\experiments\output_full\output_txt\007482_params.txt
# Inside apply_reverb: received ir_length = 11605
# Saved audio for 007482 to ..\experiments\output_full\output_audio
#
# Processing song: ..\data\raw\fma_small\007\007483.mp3
# Parameters for 007483 saved to ..\experiments\output_full\output_txt\007483_params.txt
# Inside apply_reverb: received ir_length = 9770
# Saved audio for 007483 to ..\experiments\output_full\output_audio
#
# Processing song: ..\data\raw\fma_small\007\007487.mp3
# Parameters for 007487 saved to ..\experiments\output_full\output_txt\007487_params.txt
# Inside apply_reverb: received ir_length = 9679
# Saved audio for 007487 to ..\experiments\output_full\output_audio
#
# Processing song: ..\data\raw\fma_small\007\007488.mp3
# Parameters for 007488 saved to ..\experiments\output_full\output_txt\007488_params.txt
# Inside apply_reverb: received ir_length = 5010
# Saved audio for 007488 to ..\experiments\output_full\output_audio
#
# Processing song: ..\data\raw\fma_small\007\007489.mp3
# Parameters for 007489 saved to ..\experiments\output_full\output_txt\007489_params.txt
# Inside apply_reverb: received ir_length = 10100
# Saved audio for 007489 to ..\experiments\output_full\output_audio
#
# Processing song: ..\data\raw\fma_small\007\007490.mp3
# Parameters for 007490 saved to ..\experiments\output_full\output_txt\007490_params.txt
# Inside apply_reverb: received ir_length = 5970
# Saved audio for 007490 to ..\experiments\output_full\output_audio
#
# Processing song: ..\data\raw\fma_small\007\007491.mp3
# Parameters for 007491 saved to ..\experiments\output_full\output_txt\007491_params.txt
# Inside apply_reverb: received ir_length = 5707
# Saved audio for 007491 to ..\experiments\output_full\output_audio
#
# Processing song: ..\data\raw\fma_small\007\007492.mp3
# Parameters for 007492 saved to ..\experiments\output_full\output_txt\007492_params.txt
# Inside apply_reverb: received ir_length = 11906
# Saved audio for 007492 to ..\experiments\output_full\output_audio
#
# Processing song: ..\data\raw\fma_small\007\007495.mp3
# Parameters for 007495 saved to ..\experiments\output_full\output_txt\007495_params.txt
# Inside apply_reverb: received ir_length = 5563
# Saved audio for 007495 to ..\experiments\output_full\output_audio
#
# Processing song: ..\data\raw\fma_small\007\007526.mp3
# Parameters for 007526 saved to ..\experiments\output_full\output_txt\007526_params.txt
# Inside apply_reverb: received ir_length = 7440
# Saved audio for 007526 to ..\experiments\output_full\output_audio
#
# Processing song: ..\data\raw\fma_small\007\007527.mp3
# Parameters for 007527 saved to ..\experiments\output_full\output_txt\007527_params.txt
# Inside apply_reverb: received ir_length = 7083
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[9], line 85
#      79 #Saving modified spectrogram image with extra info annotation
#      80 extra = (f"EQ: fc={fc:.2f} Hz, Q={Q:.2f}, gain_db={eq_gain_db:.2f}\n"
#      81         f"Gain: {gain_db:.2f} dB\n"
#      82         f"Echo: delay={delay_seconds:.2f}s, att={attenuation:.2f}\n"
#      83         f"Reverb: decay={decay:.2f}, IR_len={ir_length}\n"
#      84         f"Comp: thr={threshold_db:.2f} dB, ratio={ratio:.2f}, makeup={makeup_gain_db:.2f} dB")
# ---> 85 fig_mod = plot_stft(modified_audio, sr, f"Modified Audio STFT - {song_id}", extra_info=extra)
#      86 mod_spec_path = os.path.join(output_spectrogram_dir, f"{song_id}_output.png")
#      87 fig_mod.savefig(mod_spec_path)
#
# Cell In[8], line 15, in plot_stft(audio, sr, title, extra_info)
#      13 def plot_stft(audio, sr, title, extra_info = None):
#      14     D = librosa.stft(audio)  # Compute STFT
# ---> 15     DB = librosa.amplitude_to_db(np.abs(D), ref=np.max)  # Convert amplitude to dB
#      17     fig, ax = plt.subplots(figsize=(12, 6))
#      19     img = librosa.display.specshow(DB, sr=sr, x_axis='time', y_axis='hz', ax=ax)
#
# File c:\Users\takak\anaconda3\envs\thesis_env\lib\site-packages\librosa\core\spectrum.py:1972, in amplitude_to_db(S, ref, amin, top_db)
#    1969 out_array = magnitude if isinstance(magnitude, np.ndarray) else None
#    1970 power = np.square(magnitude, out=out_array)
# -> 1972 db: np.ndarray = power_to_db(power, ref=ref_value**2, amin=amin**2, top_db=top_db)
#    1973 return db
#
# File c:\Users\takak\anaconda3\envs\thesis_env\lib\site-packages\librosa\core\spectrum.py:1814, in power_to_db(S, ref, amin, top_db)
#    1811 else:
#    1812     ref_value = np.abs(ref)
# -> 1814 log_spec: np.ndarray = 10.0 * np.log10(np.maximum(amin, magnitude))
#    1815 log_spec -= 10.0 * np.log10(np.maximum(amin, ref_value))
#    1817 if top_db is not None:
#
# MemoryError: Unable to allocate 20.2 MiB for an array with shape (1025, 2582) and data type float64
